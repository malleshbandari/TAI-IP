# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\Mallesh\\Downloads\\archive (1).zip")
data
# Out:
#                    country_name         city_name  aqi_value aqi_category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        co_aqi_value\t co_aqi_category  ozone_aqi_value ozone_aqi_category  \
# ...

# %%
data.columns
# Out:
# Index(['country_name', 'city_name', 'aqi_value', 'aqi_category',
#        'co_aqi_value\t', 'co_aqi_category', 'ozone_aqi_value',
#        'ozone_aqi_category', 'no2_aqi_value', 'no2_aqi_category',
#        'pm2.5_aqi_value', 'pm2.5_aqi_category'],
#       dtype='object')

# %%
data.head()
# Out:
#          country_name         city_name  aqi_value aqi_category  \
# 0  Russian Federation        Praskoveya         51     Moderate
# 1              Brazil  Presidente Dutra         41         Good
# 2               Italy   Priolo Gargallo         66     Moderate
# 3              Poland         Przasnysz         34         Good
# 4              France          Punaauia         22         Good
#
#    co_aqi_value\t co_aqi_category  ozone_aqi_value ozone_aqi_category  \
# 0               1            Good               36               Good
# 1               1            Good                5               Good
# 2               1            Good               39               Good
# 3               1            Good               34               Good
# 4               0            Good               22               Good
#
#    no2_aqi_value no2_aqi_category  pm2.5_aqi_value pm2.5_aqi_category
# 0              0             Good               51           Moderate
# ...

# %%
data.tail()
# Out:
#                    country_name     city_name  aqi_value aqi_category  \
# 23458                     India  Gursahaiganj        184    Unhealthy
# 23459                    France        Sceaux         50         Good
# 23460                     India      Mormugao         50         Good
# 23461  United States of America   Westerville         71     Moderate
# 23462                  Malaysia        Marang         70     Moderate
#
#        co_aqi_value\t co_aqi_category  ozone_aqi_value ozone_aqi_category  \
# 23458               3            Good              154          Unhealthy
# 23459               1            Good               20               Good
# 23460               1            Good               22               Good
# 23461               1            Good               44               Good
# 23462               1            Good               38               Good
#
#        no2_aqi_value no2_aqi_category  pm2.5_aqi_value pm2.5_aqi_category
# ...

# %%
data.dtypes
# Out:
# country_name          object
# city_name             object
# aqi_value              int64
# aqi_category          object
# co_aqi_value\t         int64
# co_aqi_category       object
# ozone_aqi_value        int64
# ozone_aqi_category    object
# no2_aqi_value          int64
# no2_aqi_category      object
# pm2.5_aqi_value        int64
# pm2.5_aqi_category    object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country_name        23036 non-null  object
#  1   city_name           23462 non-null  object
#  2   aqi_value           23463 non-null  int64
#  3   aqi_category        23463 non-null  object
#  4   co_aqi_value	       23463 non-null  int64
#  5   co_aqi_category     23463 non-null  object
#  6   ozone_aqi_value     23463 non-null  int64
#  7   ozone_aqi_category  23463 non-null  object
#  8   no2_aqi_value       23463 non-null  int64
#  9   no2_aqi_category    23463 non-null  object
#  10  pm2.5_aqi_value     23463 non-null  int64
#  11  pm2.5_aqi_category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %%
integers=data.select_dtypes(include=['int64'])
integers
# Out:
#        aqi_value  co_aqi_value\t  ozone_aqi_value  no2_aqi_value  \
# 0             51               1               36              0
# 1             41               1                5              1
# 2             66               1               39              2
# 3             34               1               34              0
# 4             22               0               22              0
# ...          ...             ...              ...            ...
# 23458        184               3              154              2
# 23459         50               1               20              5
# 23460         50               1               22              1
# 23461         71               1               44              2
# 23462         70               1               38              0
#
#        pm2.5_aqi_value
# 0                   51
# 1                   41
# 2                   66
# 3                   20
# 4                    6
# ...                ...
# ...

# %%
len(data)
# Out:
# 23463

# %%
len(data.columns)
# Out:
# 12

# %%
data.shape
# Out:
# (23463, 12)

# %%
data.size
# Out:
# 281556

# %%
data.ndim
# Out:
# 2

# %%
d=data.shape
d[0]
# Out:
# 23463

# %%
d[1]
# Out:
# 12

# %%
data.isna()
# Out:
#        country_name  city_name  aqi_value  aqi_category  co_aqi_value\t  \
# 0             False      False      False         False           False
# 1             False      False      False         False           False
# 2             False      False      False         False           False
# 3             False      False      False         False           False
# 4             False      False      False         False           False
# ...             ...        ...        ...           ...             ...
# 23458         False      False      False         False           False
# 23459         False      False      False         False           False
# 23460         False      False      False         False           False
# 23461         False      False      False         False           False
# 23462         False      False      False         False           False
#
#        co_aqi_category  ozone_aqi_value  ozone_aqi_category  no2_aqi_value  \
# ...

# %%
data.isnull()
# Out:
#        country_name  city_name  aqi_value  aqi_category  co_aqi_value\t  \
# 0             False      False      False         False           False
# 1             False      False      False         False           False
# 2             False      False      False         False           False
# 3             False      False      False         False           False
# 4             False      False      False         False           False
# ...             ...        ...        ...           ...             ...
# 23458         False      False      False         False           False
# 23459         False      False      False         False           False
# 23460         False      False      False         False           False
# 23461         False      False      False         False           False
# 23462         False      False      False         False           False
#
#        co_aqi_category  ozone_aqi_value  ozone_aqi_category  no2_aqi_value  \
# ...

# %%
data.isna().sum()
# Out:
# country_name          427
# city_name               1
# aqi_value               0
# aqi_category            0
# co_aqi_value\t          0
# co_aqi_category         0
# ozone_aqi_value         0
# ozone_aqi_category      0
# no2_aqi_value           0
# no2_aqi_category        0
# pm2.5_aqi_value         0
# pm2.5_aqi_category      0
# dtype: int64

# %%
data1=data.dropna()
data1
# Out:
#                    country_name         city_name  aqi_value aqi_category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        co_aqi_value\t co_aqi_category  ozone_aqi_value ozone_aqi_category  \
# ...

# %%
data1.isna().sum()
# Out:
# country_name          0
# city_name             0
# aqi_value             0
# aqi_category          0
# co_aqi_value\t        0
# co_aqi_category       0
# ozone_aqi_value       0
# ozone_aqi_category    0
# no2_aqi_value         0
# no2_aqi_category      0
# pm2.5_aqi_value       0
# pm2.5_aqi_category    0
# dtype: int64

# %%
data1.describe()
# Out:
#           aqi_value  co_aqi_value\t  ozone_aqi_value  no2_aqi_value  \
# count  23035.000000    23035.000000     23035.000000   23035.000000
# mean      72.344693        1.376254        35.233905       3.084741
# std       56.360992        1.844926        28.236613       5.281708
# min        6.000000        0.000000         0.000000       0.000000
# 25%       39.000000        1.000000        21.000000       0.000000
# 50%       55.000000        1.000000        31.000000       1.000000
# 75%       80.000000        1.000000        40.000000       4.000000
# max      500.000000      133.000000       235.000000      91.000000
#
#        pm2.5_aqi_value
# count     23035.000000
# mean         68.883482
# std          55.057396
# min           0.000000
# 25%          35.000000
# 50%          54.000000
# 75%          79.000000
# max         500.000000

# %%
# 3. Bar Plots for AQI categories
plt.figure(figsize=(12, 8))
for i, col in enumerate(['aqi_category', 'co_aqi_category', 'ozone_aqi_category', 'no2_aqi_category', 'pm2.5_aqi_category']):
    plt.subplot(2, 3, i+1)
    sns.countplot(x=col, data=data1)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# 4. Histograms for AQI values
plt.figure(figsize=(12, 8))
for i, col in enumerate(['aqi_value', 'co_aqi_value\t', 'ozone_aqi_value', 'no2_aqi_value', 'pm2.5_aqi_value']):
    plt.subplot(2, 3, i+1)
    sns.histplot(data1[col], bins=20, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Mallesh\AppData\Local\Temp\ipykernel_15500\3675676985.py:9: UserWarning: Glyph 9 (	) missing from current font.
#   plt.tight_layout()
# C:\Users\Mallesh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 5. Scatter Plots
plt.figure(figsize=(12, 8))
sns.pairplot(data1[['aqi_value', 'co_aqi_value\t', 'ozone_aqi_value', 'no2_aqi_value', 'pm2.5_aqi_value']])
plt.title('Scatter Plot for AQI values')
plt.show()
# Out:
# C:\Users\Mallesh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 9 (	) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Mallesh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Mallesh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
correlation=integers.corr()

# %%
# Plotting correlation matrix heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\Mallesh\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# C:\Users\Mallesh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='country_name', y='pm2.5_aqi_value', data=data1)
plt.title('Distribution of PM2.5 AQI Values Across Countries')
plt.xlabel('Country')
plt.ylabel('PM2.5 AQI Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plotting the line graph
plt.figure(figsize=(10, 6))
sns.lineplot(data=data1, x='country_name', y='aqi_value',  marker='o', linestyle='-')
plt.title('AQI Value by Country and City')
plt.xlabel('City')
plt.ylabel('AQI Value')
plt.legend(title='Country')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
